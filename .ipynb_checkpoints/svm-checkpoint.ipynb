# %%
import pandas as pd
import re
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
import operator
from sklearn.svm import SVC

df = pd.read_csv("mind_sharing1.csv")


df = df.reset_index(drop=True)

REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    """
        text: a string
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    #text = text.replace('x', '')
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text
df['body'] = df['body'].apply(clean_text)
df['body'] = df['body'].str.replace('\d+', '')


#######################################################################################

def depression_predictions(df, new_text):
    
    #one hot encoding
    code = []
    for tag in df['tags']:
        if 'depression' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code

    # select the columns we need
    df = df[['body', 'code']]
    
    # split into test and train
    Y = df['code'].values
    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)

    # transform texts to arrays
    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)
    
    
    #build model
    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    # transform new text to array
    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    # get the prediction probability of the new text
    depression_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return depression_score

#######################################################################

def anxiety_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'anxiety' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code

    df = df[['body', 'code']]
    Y = df['code'].values
    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)


    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    anxiety_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return anxiety_score

#######################################################################

def grief_loss_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'grief & loss' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    grief_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return grief_score

###################################################################

def self_esteem_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'self esteem & confidence' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    self_esteem_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return self_esteem_score

##################################################################################

def stress_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'stress' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    stress_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return stress_score

####################################################################

def relationship_issues_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'relationship issues' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    relationship_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return relationship_score

############################################################

def work_professional_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'work/professional/career' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    work_score = list(classifier.predict_proba(transform_text)[:,0])[0]

    return work_score

#################################################################

def trauma_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'trauma' in tag:
            tag = 0
            code.append(tag)
        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    trama_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return trama_score

####################################################################

def abuse_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'abuse' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    abuse_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return abuse_score

###########################################################################3

def anger_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'anger' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    anger_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return anger_score

#################################################################################

def sexuality_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'sexuality' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    sexuality_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return sexuality_score

########################################################################

def eating_disorder_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'eating disorder' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    eating_disorder_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return eating_disorder_score

###############################################################

def addictions_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'addictions' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    addictions_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return addictions_score

#######################################################################

def sex_related_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'sex-related' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    sex_related_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return sex_related_score

#########################################################################################

def adhd_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'ADHD' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    adhd_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return adhd_score

    
##############################################################################

def sleeping_disorders_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'sleeping disorders' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    sleeping_disorders_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return sleeping_disorders_score


#######################################################################

def others_predictions(df, new_text):
    code = []
    for tag in df['tags']:
        if 'others' in tag:
            tag = 0
            code.append(tag)

        else:
            tag = 1
            code.append(tag)
    df['code'] = code


    df = df[['body', 'code']]
    
    
    Y = df['code'].values

    df_train, df_test, Ytrain, Ytest = train_test_split(df['body'], Y, test_size=0.33, random_state=0)


    tfidf = TfidfVectorizer(decode_error='ignore')
    Xtrain = tfidf.fit_transform(df_train)

    #model_2 = LogisticRegression()
    svm = SVC(random_state= 1, probability=True)
    classifier = OneVsRestClassifier(svm)
    classifier.fit(Xtrain, Ytrain)

    text_series = pd.Series([new_text])
    transform_text = tfidf.transform(text_series)

    
    others_score = list(classifier.predict_proba(transform_text)[:,0])[0]
    
    return others_score

# %%
def process_all_predictions(new_text):
    depression_score = depression_predictions(df, new_text)
    anxiety_score = anxiety_predictions(df, new_text)
    grief_score = grief_loss_predictions(df, new_text)
    self_esteem_score = self_esteem_predictions(df, new_text)
    stress_score = stress_predictions(df, new_text)
    relationship_score = relationship_issues_predictions(df, new_text)
    work_profession_score = work_professional_predictions(df, new_text)
    trauma_score = trauma_predictions(df, new_text)
    abuse_score = abuse_predictions(df, new_text)
    anger_score = anger_predictions(df, new_text)
    sexuality_score = sexuality_predictions(df, new_text)
    eating_disorder_score = eating_disorder_predictions(df, new_text)
    addictions_score = addictions_predictions(df, new_text)
    sex_related_score = sex_related_predictions(df, new_text)
    adhd_score = adhd_predictions(df, new_text)
    sleeping_disorder_score = sleeping_disorders_predictions(df, new_text)
    others_score = others_predictions(df, new_text)

    
    
    items_scores = {"depression_score": depression_score, "anxiety_score": anxiety_score,
                   "grief_score":grief_score, "self_esteem_score": self_esteem_score,
                    "stress_score":stress_score, "relationship_score": relationship_score,
                   "work_profession_score": work_profession_score, "trauma_score":trauma_score,
                   "abuse_score":abuse_score, "anger_score":anger_score, "sexuality_score": sexuality_score,
                   "eating_disorder_score":eating_disorder_score, "addictions_score":addictions_score,
                   "sex_related_score": sex_related_score, "adhd_score":adhd_score,
                    "sleeping_disorder_score":sleeping_disorder_score, "others_score":others_score}
    
    
    sorted_score = dict(sorted(items_scores.items(), key=operator.itemgetter(1),reverse=True))
    
    text_and_score = {new_text : [sorted_score]}
    
    
    return text_and_score

# %%
# new_text = "I think I have always had a mix of anxiety and depression with one frequently kicking the other off. I get anxious when I am depressed and depressed when I am anxious, very difficult to see the dividing line. I don't think any of these things can be pinned down very precisely what just exacerbates the way patients are treated by the professionals."

# process_all_predictions(new_text)

# %%
new_text = "After having several episodes of anxiety attacks. Ukeme blogs about depression"

process_all_predictions(new_text)

# %%
list(hi[new_text][0].items())[:2]
# Out:
# [('anxiety_score', 0.9981616160844955)]

# %%
hi[new_text][0]
# Out:
# {'anxiety_score': 0.9981616160844955,
#  'depression_score': 0.5,
#  'stress_score': 0.2744559477227092,
#  'self_esteem_score': 0.045755022094701614,
#  'relationship_score': 0.033275793631775685,
#  'grief_score': 0.02915969973048893,
#  'sleeping_disorder_score': 0.02386491117378109,
#  'adhd_score': 0.02328093978568002,
#  'trauma_score': 0.015964887051031718,
#  'sexuality_score': 0.015101929753155163,
#  'work_profession_score': 0.008124325893411832,
#  'others_score': 0.0067337232620861,
#  'abuse_score': 0.0047524336444091375,
#  'sex_related_score': 0.002980588441918841,
#  'eating_disorder_score': 0.0026824150662534407,
#  'addictions_score': 1.1020004955786256e-05,
#  'anger_score': 1.0918803584170078e-05}

# %%
df
# Out:
#                             _id                                         title  \
# 0      603557ee4b91547ef673cfdc  Anxiety and Depression: Which one do I have?
# 1      603557ee4b91547ef673cfdd  Anxiety and Depression: Which one do I have?
# 2      603557ef4b91547ef673cfde  Anxiety and Depression: Which one do I have?
# 3      603557ef4b91547ef673cfdf  Anxiety and Depression: Which one do I have?
# 4      603557f14b91547ef673cfe0  Anxiety and Depression: Which one do I have?
# ...                         ...                                           ...
# 43887  603f5e5fe55998eba33bb298                                   Just tired.
# 43888  603f5e5fe55998eba33bb299                                   Just tired.
# 43889  603f5e5fe55998eba33bb29a                                   Just tired.
# 43890  603f5e7ce55998eba33bb29b                          I feel like im stuck
# 43891  603f5ea8e55998eba33bb29c                      Advice for the depressed
#
#                      name                                               body  \
# 0                mischief  David Carbonell, a psychologist who does a lot...
# 1               Rose19602  Thanks for that. I could relate to the depress...
# 2                 BedHead  ok, I read the article... it's very interestin...
# 3      mental health girl  Thanks for sharing the article, for me i got a...
# 4                   mami5  Hi I've just read the article and now I am mor...
# ...                   ...                                                ...
# 43887            Jamesdeo  Ive been suffering from suicidal thoughts for ...
# 43888              Talina  Hi Jamesdeo and welcome to the forum, I’m sorr...
# 43889              NWiddi  I've found some Russian specific services that...
# 43890    lifecangetbetter  but i miss school. i used to be able to study ...
# 43891   TheHeartHasAVoice  \n\nMistral said:\n\n\n\n\t\t\tCould you give ...
#
#                                                     link
# 0      https://www.mentalhealthforum.net/forum/thread...
# 1      https://www.mentalhealthforum.net/forum/thread...
# 2      https://www.mentalhealthforum.net/forum/thread...
# 3      https://www.mentalhealthforum.net/forum/thread...
# 4      https://www.mentalhealthforum.net/forum/thread...
# ...                                                  ...
# 43887  https://www.mentalhealthforum.net/forum/thread...
# 43888  https://www.mentalhealthforum.net/forum/thread...
# 43889  https://www.mentalhealthforum.net/forum/thread...
# 43890  https://www.mentalhealthforum.net/forum/thread...
# 43891  https://www.mentalhealthforum.net/forum/thread...
#
# [43892 rows x 5 columns]

# %%
import pandas as pd
dff = pd.read_csv("depression_forum.csv")

# %%
updated_text = []
for text in dff['body']: #.head(100):
    if "Click to expand..." not in text:
        updated_text.append(text)
        #print((text))
        #print("--------------------")
len(updated_text)
# Out:
# 32446

# %%
len(dff['body'])
# Out:
# 43892

# %%
#updated_text = []
for text in dff['body']: #.head(100):
    if "suicidal"  in text and "Click to expand..." not in text:
        hi = process_all_predictions(text)
        hello = list(hi[text][0].items())[:2]
        #updated_text.append(text)
        print((text))
        print(hello)
        print("--------------------")
#len(updated_text)
# Out:
# I have just been on a course Understanding Depression and Anxiety and you can definitely have both together. Anxiety is often a reaction to situations you find unpleasant so you get panic attacks, shaking and leg wobbling. Depression is more when you have feelings of not wanting to take part in life so you don't want to get up or go out and in extreme cases have self harm and suicidal thoughts.
# [('depression_score', 0.9880543319199724), ('anxiety_score', 0.7386566351883233)]
# --------------------
# I am new to forum. I suffer from clinical depression. Mine always starts with anxiety. Currently suffering. I have had all physical signs. My body is shaking inside. I can't stop shaking my legs or body. Can't sleep. Lost stone in weight within a week. Can't stop crying all the time. Nil energy. Self loath all the time. Pins and needles in hands arms feet. My gums are sore. It's horrible thoughts which are worse. I do not feel suicidal but have done in past. I get fed up when people ask me how I stay slim. I wish I was just happy that's all I want.
# [('depression_score', 0.4746985739292098), ('anxiety_score', 0.44862780443921113)]
# --------------------
# I have suffered from depression occasionally throughout my adult life. Now I'm 61 and effectively retired I don't have the pressures and strains that used to bring on depressive feelings but I'm almost suicidal. I found CBT and exercise to be useful, but pharmaceuticals and counselling did little, if anything, for me.  Although I'm what might be called an unstable personality (despite my being one of the most sensible, pragmatic, logical and unemotional people you'll meet) I think my current depression comes from an issue that has been getting worse throughout my adult life: I don't seem to get refreshing sleep and I feel [email protected] during the day.  The extra tiredness and lack of motivation through depression is killing me.
#
# I was diagnosed with apnoea 5 years ago but CPAP worked only marginally.  A review diagnosed me with central sleep apnoea, where the apnoea is linked to my brain not a throat obstruction, but the more complicated BiPAP machine made no difference.  I have RLS and PLMS, where I twitch at night and during sleep, but 3 different drugs have made no difference.  I've had my machine settings tuned by hospital and the experts on Apnoea boards but nothing helps. There are many clinical studies on Apnoea's being linked to depression but none I can find on my situation.
#
# Does anyone have experience of depression and sleep disorders, Apnoea in particular?
# [('depression_score', 0.9933225429843991), ('sleeping_disorder_score', 0.9744039326946612)]
# --------------------
# Hello  Beautifuldarkfsntasy,
#
# I'm so sorry that you are suffering the way that you are. If you would like to share some of what's going on, I'd be more than happy to listen. I know you said you are living in a place you hate, and you hate the people you live with, but 'what' do you hate about it/them? If you don't care to go into detail, I understand that. I wish there was something of more value to say to you besides I'm here to listen if you want to talk, but that's all I have. I have suffered with suicidal thoughts in my past, depression, anxiety and social phobia (from childhood), so I literally understand how it feels to want to die.
#
# January
# [('anxiety_score', 0.6852167180995667), ('depression_score', 0.5352785985869237)]
# --------------------
# Having a passive suicidal thought is one of the symptoms of depression, nothing more.
# [('depression_score', 0.9801196729076215), ('trauma_score', 0.3745306447467589)]
# --------------------
# I have passive suicidal thoughts almost on a daily basis. I wish I could know how to stop them. I say to my psychiatrist every time I see him about these thoughts, but I don't get a response from him on how to stop them. I'll ask him directly on my next visit how I can stop them. Perhaps he'll refer me to a therapist.
# [('anxiety_score', 0.4760418138711472), ('others_score', 0.1924052650882252)]
# --------------------
# I'm sorry you're feeling so low, I hope things improve for you soon. It may help to have a look at these two pages on the forum: Suicidal Crisis and Mental Health Forum - Getting Help about what to do if you're feeling suicidal, or if you need emergency help. I hope you can use the forum for support during this difficult time.
#
# If you’re thinking about suicide and are in immediate danger, please call your local emergency number (i.e. in the UK call 999, in the USA or Canada call 911, in Australia call 000 and in New Zealand call 111) or call the international emergency number of 112.
#
# If you have been affected by the contents of this thread and would like to speak to someone about your feelings you can call one of the following helplines:
#
# In the UK and Ireland, the Samaritans can be contacted on 116 123.
# In the US, the National Suicide Prevention Lifeline is 1-800-273-8255.
# In Canada, the Suicide Prevention Service on 1.833.456.4566.
# In Australia, the crisis support service Lifeline is on 13 11 14.
# In New Zealand, the Need to Talk service is on 1737 or 080017371737.
# Other international helplines can be found at www.befrienders.org.
# [('anxiety_score', 0.44119252085460303), ('others_score', 0.3135984144460442)]
# --------------------
# Hi, I'm a new member and today I was driven to the edge and didn't know what to do. I texted a suicide line but they replied with very generic words and it wasn't very helpful.
#
# I've suffered with depression since I was 11 years old (28 now) due to a mentally abusive father. I tried therapies and medicine but nothing seemed to really work for me. So I've dealt with it myself, had better and worse days. After moving to UK 5 years ago it all seemed to get better, I started some self development, managed to find a path of career i want to follow and met a wonderful man.
# I know you'll have been given this information by your GP and I doubt it will be of any use to you which I apologise for but for others who may have come here because they too are experiencing what you have been I'll post it any way.
#
# It may help to have a look at these two pages on the forum: Suicidal Crisis and Mental Health Forum - Getting Help about what to do if you're feeling suicidal, or if you need emergency help.
#
# If you’re thinking about suicide and are in immediate danger, please call your local emergency number (i.e. in the UK call 999, in the USA or Canada call 911, in Australia call 000 and in New Zealand call 111) or call the international emergency number of 112.
#
# If you have been affected by the contents of this thread and would like to speak to someone about your feelings you can call one of the following helplines:
#
# In the UK and Ireland, the Samaritans can be contacted on 116 123.
# In the US, the National Suicide Prevention Lifeline is 1-800-273-8255.
# In Canada, the Suicide Prevention Service on 1.833.456.4566.
# In Australia, the crisis support service Lifeline is on 13 11 14.
# In New Zealand, the Need to Talk service is on 1737 or 080017371737.
# Other international helplines can be found at www.befrienders.org.
#
# If you feel there's anything the team here can do for you please don't hesitate to ask.
# [('anxiety_score', 0.4695581765329625), ('trauma_score', 0.32095056159325497)]
# --------------------
# Know that there will be better days for you. Your suicidal and negative thoughts will pass. It is not permanent.
#
# Listen to uplifting and encouraging songs on youtube. Music helps a lot and is therapeutic.
#
# When you begin to think of suicide, switch your thoughts to good and positive things and do something good instead.
# [('sleeping_disorder_score', 0.4342218651462034), ('anxiety_score', 0.3454914188059296)]
# --------------------
# I'm sorry you feel this way, I found this service for Brazil, I don't know if they can help but may be worth a try? Your life is worth fighting for.
#
# Centro de Valorização da Vida (CVV | Centro de Valorização da Vida) is an emotional and suicidal prevention support NGO founded in 1962 in São Paulo, Brazil, and recognized as Federal Public Utility in 1973. It offers voluntary and free support, with all communications being confidential. Contacts can be made through the phone number 141 (available 24/7), personally (in one of the 72 centres around the country), chat (via their website), VoIP (via Skype) and e-mail.
#
# [('trauma_score', 0.4179171724760926), ('anxiety_score', 0.34344172485140556)]
# --------------------
# If you have these thoughts please talk to someone who knows what to do. NHS inform has numbers for the helplines open at this time.
# You really should phone your GP right now. You are experiencing suicidal ideation - a serious and ‘needs to be dealt with now’ symptom.
# I missed my Christmas Day (and only day) with my Mum and Dad due to exhaustion from not being able to sleep before (too busy organising everything).
# I think you should dial the doctor right now and explain. Please.
# [('anxiety_score', 0.4700620421564752), ('sleeping_disorder_score', 0.306445007747402)]
# --------------------
# Age matters not. Have you seen me before you? Spoiler alert, he has an accident, gives himself 6 months to live, meets a wonderful woman and actually lives a decent life. It's just not his life that he wants, and he ends it.
#
# All I need is good quality sleep every night. Without it, I am nothing. With it, I am no where near suicidal despite my struggles. My life is being wasted, just passing by as I am tortured. If you were tortured, wouldn't you prefer just to die?
#
# I can see through to the good and yet I still acknowledge that if I don't sleep, I don't want it, and I will not carry on. I could offer so many great things to this world if I could sleep. A "normal" life seems like a dream to me. I have an abundance of good things. I have water, food, etc. I can leave the tap running all day every day and it will never stop. There is no reason whatsoever why I shouldn't sleep. I am not being tortured in the normal sense, but insomnia is torture. I am not tired when you just have to deal with it. I'm absolutely exhausted. In fact that doesn't even describe it. I am dying inside. Parts of me are already dead and can never return.
#
# Yet, despite all that, I can see a good life worth living IF I SLEEP. But I don't. So I'm at my end.
# [('sleeping_disorder_score', 0.9996819408964646), ('anxiety_score', 0.33242605655095325)]
# --------------------
# I have passive suicidal thoughts almost on a daily basis. Sometimes I get into a loop and it's very difficult to get out of it. My previous nurse practitioner thought I had OCD with suicidal ideation. My current psychiatrist never brought up this diagnosis. Here is what the difference between passive and active suicidality is:
#
# If  you are in crisis, please call the National Suicide Prevention Lifeline at 1-800-273-8255.
#
# Passive vs. active suicidality is something some people have problems wrapping their heads around. I can say with absolute certainty I’m suicidal… I have been for almost a year now. However, it’s passive. The difference between the two is very simple (but also super complex). Being passively suicidal means you wish to die. Actively suicidal is just that — you’ve got your plan and you’re planning on going through with the plan.
# [('trauma_score', 0.4788281340067231), ('anxiety_score', 0.44484798398430603)]
# --------------------
# Some copy and paste was used in my previous post. I've had passive suicidal thoughts for years.
# [('anxiety_score', 0.3142879052616707), ('depression_score', 0.29189087486946286)]
# --------------------
# When I get triggered badly in relationships, I will start thinking passive suicidal thoughts. Or what purpleplum said. It is unpredictable but it doesn’t happen too often. Not lately, at least. I’m sorry it is every day for years. That’s horrible to live with.
# [('anxiety_score', 0.44333168978802306), ('work_profession_score', 0.17323410790938754)]
# --------------------
# Those passive suicidal thoughts for me are comforting and a coping mechanism. I had them frequently when I was ill. Still do sometimes. It's just like, wouldn't it be good to not struggle anymore? In lieu of actually having a better life there is comfort in imagining no more struggle. Seems like an aspect of suicidal thinking that people may overlook, as though it's bad to have such thoughts. I find them valuable.
# [('anxiety_score', 0.36971052703084795), ('depression_score', 0.2658284939890495)]
# --------------------
# I have very passive suicidal thoughts almost every day. So passive that I don't even want to do it, I don't even really mean to think it. Then actually not wanting to be alive probably happens every one or two weeks but without the intention to act on it despite how much I sometimes want to.
# [('anxiety_score', 0.472762169589485), ('trauma_score', 0.291503138887396)]
# --------------------
# i have learnt something here i didnt know the term passive suicidality it kind of fits how ive been feeling for many years off and on but its more like i just want there to be nothing no more hurt or pain or sadness i don't want to die but it's the only way i can see to stop feeling this way sorry if i havent made a lot of sense
# [('anxiety_score', 0.4024494255972547), ('others_score', 0.22554323830483702)]
# --------------------
# Lately passive suicidality most every day and active suicidality about every other day. I hadn’t heard of the distinction used before so thanks for bringing it up today. It makes a lot of sense. xo, j
# [('anxiety_score', 0.4133424257849361), ('work_profession_score', 0.30018258528438047)]
# --------------------
# I'm amazed at how common suicidal ideation is among depressed persons. I guess that's why psychiatrists don't show a reaction when a depressed person expresses a passive suicidal thought to them.
# [('depression_score', 0.42271717356263416), ('anxiety_score', 0.35964272603054726)]
# --------------------
# What scares me the most is acting upon a suicidal thought impulsively.
# [('trauma_score', 0.5553975881776505), ('anxiety_score', 0.38173734512899027)]
# --------------------
#
# I've been prescribed propranolol from the doctor at the end of last week, and I've been taking it for 2/3 days but it doesn't seem to be calming my anxiety.
#
# Any advice on returning to work following a period of absence for depression?
# [('anxiety_score', 0.7666084738765623), ('depression_score', 0.5292763370051237)]
# --------------------
# Hi,
#
# I’m sorry to bother you all but I’m not sure who else to speak with.
# I have been suffering from double vision for almost 2 years now with no current diagnosis. I was on steroids for around 3 months to try and help the issue but the only thing it did was put a lot of weight on me.
# So at the moment I am around 5 stone over weight, my blood pressure is through the roof and I need to see the doctor about that, I’ve still got double vision and I am walking round with glasses on that have frosting over one lense making me look stupid and causing people to look and stare.
# I know I need to lose weight but I don’t seem to have the drive and determination to do it cause I am so unhappy and miserable cause of my condition so I comfort eat. It’s like a vicious circle!!
# I am not feeling suicidal or anything like that. But I’m just miserable and making the people around me miserable!
# [('others_score', 0.27063600291074086), ('anxiety_score', 0.26217672243500123)]
# --------------------
# I know a lot of people suffer from depression and anxiety and feel down, sad etc but I literally want to die everyday! Every secenario I come across tips me over: A) I wait for the next bus B) go home C) kill myself.
#
# I 18! I have been suicidal since as long as I can remember, I remember in primary school I would cry in my bedroom saying to myself I want to die or I want to go home(even if I already was because I didn’t feel like my home was a home) and get jealous of all my other class mates as they were happy and had nice lives! I got bullied at multiple schools which ended when I got older but also had verbal abuse at home. My eldest brother committed suicide and my family are really negative. I attempted suicide when I was 12 ( bad, I know) by taking loads of paracetamol that was too slow of a process so like most people, ended up in hospital and that was when I knew if I was ever going to attempt suicide again I would do it properly, irreversible and quickly.
# I moved away from my toxic family when I was 16 and live by myself and am doing a levels trying to go to uni but I have no hope! Even if I do go to uni I just don’t see the point in living and nothing seems worth another day of pain! One thing I’ve always wanted to do was adopt kids, I am a caring person (I’m also vegan) and I just wish I could skip to the bit where I have the money to be able to give people in similar or worse situations to me a better life but I’ve given up because the amount of work I have to do to get there isn’t actually possible with the limited energy I have  I don’t think Theres anything anyone can do or recommend but feel free to reply or share any similar experiences
# [('trauma_score', 0.6267025450625323), ('anxiety_score', 0.5958534219243317)]
# --------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-2b3d0db9e88c> in <module>
#       2 for text in dff['body']: #.head(100):
#       3     if "suicidal"  in text and "Click to expand..." not in text:
# ----> 4         hi = process_all_predictions(text)
#       5         hello = list(hi[text][0].items())[:2]
#       6         #updated_text.append(text)
#
# <ipython-input-49-1c56962c645d> in process_all_predictions(new_text)
#      11     anger_score = anger_predictions(df, new_text)
#      12     sexuality_score = sexuality_predictions(df, new_text)
# ---> 13     eating_disorder_score = eating_disorder_predictions(df, new_text)
#      14     addictions_score = addictions_predictions(df, new_text)
#      15     sex_related_score = sex_related_predictions(df, new_text)
#
# <ipython-input-48-f12bfc6bf1cc> in eating_disorder_predictions(df, new_text)
#     493     svm = SVC(random_state= 1, probability=True)
#     494     classifier = OneVsRestClassifier(svm)
# --> 495     classifier.fit(Xtrain, Ytrain)
#     496
#     497     text_series = pd.Series([new_text])
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\sklearn\multiclass.py in fit(self, X, y)
#     239         # n_jobs > 1 in can results in slower performance due to the overhead
#     240         # of spawning threads.  See joblib issue #112.
# --> 241         self.estimators_ = Parallel(n_jobs=self.n_jobs)(delayed(_fit_binary)(
#     242             self.estimator, X, column, classes=[
#     243                 "not %s" % self.label_binarizer_.classes_[i],
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\sklearn\multiclass.py in _fit_binary(estimator, X, y, classes)
#      79     else:
#      80         estimator = clone(estimator)
# ---> 81         estimator.fit(X, y)
#      82     return estimator
#      83
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     215
#     216         seed = rnd.randint(np.iinfo('i').max)
# --> 217         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     218         # see comment on the other call to np.iinfo in this file
#     219
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\sklearn\svm\_base.py in _sparse_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     290             self.intercept_, self._n_support, \
#     291             self._probA, self._probB, self.fit_status_ = \
# --> 292             libsvm_sparse.libsvm_sparse_train(
#     293                 X.shape[1], X.data, X.indices, X.indptr, y, solver_type,
#     294                 kernel_type, self.degree, self._gamma, self.coef0, self.tol,
#
# sklearn\svm\_libsvm_sparse.pyx in sklearn.svm._libsvm_sparse.libsvm_sparse_train()
#
# c:\users\ukeme\appdata\local\programs\python\python38\lib\site-packages\scipy\sparse\compressed.py in __init__(self, arg1, shape, dtype, copy)
#      25     """base matrix class for compressed row- and column-oriented matrices"""
#      26
# ---> 27     def __init__(self, arg1, shape=None, dtype=None, copy=False):
#      28         _data_matrix.__init__(self)
#      29
#
# KeyboardInterrupt:

# %%
#updated_text = []
# for text in dff['body']: #.head(100):
#     if "suicidal"  in text and "Click to expand..." not in text:
#         hi = process_all_predictions(text)
#         hello = list(hi[text][0].items())[:2]
#         #updated_text.append(text)
#         print((text))
#         print(hello)
#         print("--------------------")
#len(updated_text)


suicidal_tag_list = []
df20 = dff.head(100)
for text in df20['body']:
    if "suicidal" in text.lower() or "suicide"  in text.lower() or "kill" in text.lower():
        suicidal_tag_list.append("suicidal")
    else:
        suicidal_tag_list.append("")


depression_tag_list = []
#df20 = dff.head(100)
for text in df20['body']:
    if "depression" in text.lower() or "depress"  in text.lower() or "depressed" in text.lower():
        depression_tag_list.append("depression")
    else:
        depression_tag_list.append("")

anxiety_tag_list = []
df20 = dff.head(100)
for text in df20['body']:
    if "anxiety" in text.lower() or "anxious"  in text.lower() or "nervous" in text.lower():
        anxiety_tag_list.append("anxiety")
    else:
        anxiety_tag_list.append("")

        
grief_loss_tag_list = []
df20 = dff.head(100)
for text in df20['body']:
    if "grief" in text.lower() or "loss"  in text.lower() or "death" in text.lower():
        grief_loss_tag_list.append("grief & loss")
    else:
        grief_loss_tag_list.append("")


self_esteem_tag_list = []
df20 = dff.head(100)
for text in df20['body']:
    if "esteem" in text.lower() or "happy"  in text.lower() or "better" in text.lower():
        self_esteem_tag_list.append("self esteem & confidence")
    else:
        self_esteem_tag_list.append("")

# %%
anxiety, depression, grief & loss , self esteem & confidence
stress, relationship issues, work/professional/career
trauma, abuse, anger, sexuality, eating disorder, addictions
Sex-related, ADHD, sleeping disorders

# %%
len(depression_tag_list)
# Out:
# 100

# %%
len(suicidal_tag_list)
# Out:
# 100

# %%
res = [a + b + c + d + e for a, b, c, d, e in zip(depression_tag_list, suicidal_tag_list, anxiety_tag_list, 
                                                  grief_loss_tag_list, self_esteem_tag_list)]

# %%
res
# Out:
# ['depressionanxiety',
#  'depressionanxietyself esteem & confidence',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  '',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depression',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxietyself esteem & confidence',
#  'depression',
#  'depressionanxietyself esteem & confidence',
#  'depressionanxietyself esteem & confidence',
#  'depressionanxietyself esteem & confidence',
#  'depressionsuicidalanxiety',
#  'depressionanxiety',
#  'depressionsuicidalanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  '',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionsuicidalanxietyself esteem & confidence',
#  'depressionanxietyself esteem & confidence',
#  '',
#  'depression',
#  'depressionanxiety',
#  '',
#  'depression',
#  'depressionanxiety',
#  '',
#  'depressionanxiety',
#  'depressionanxiety',
#  '',
#  'anxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  '',
#  'depressionanxietygrief & lossself esteem & confidence',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  '',
#  '',
#  '',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxietyself esteem & confidence',
#  'depressionanxiety',
#  'anxietyself esteem & confidence',
#  '',
#  'depressionself esteem & confidence',
#  'depressionanxietyself esteem & confidence',
#  'depressionself esteem & confidence',
#  'depression',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  'depressionanxiety',
#  '',
#  '',
#  '',
#  'self esteem & confidence',
#  '',
#  'depression',
#  '',
#  '',
#  '',
#  'depressionself esteem & confidence',
#  '',
#  '',
#  'depressionsuicidalanxiety',
#  'suicidal',
#  'anxiety',
#  'anxiety',
#  'anxietyself esteem & confidence',
#  'anxietyself esteem & confidence',
#  '']

# %%
df20['tags'] = res
# Out:
# <ipython-input-133-c2170a7f21bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df20['tags'] = res

# %%
df20[['body', 'tags']][17:18]['body'][17]
# Out:
# 'Joanna,first thing towards getting better is to accept you have an Illness .there is no shame in having a mental illness,as long as I tried to hide it It got worse,once I started to accept and started to treat it as another illness,now after suffering with depression ,anxiety,PTSD and panini attack for the last 15  years,I started work 6 years ago,told my boss,my colleagues ,my friends ,literally everyone,now I feel much better as I am not scared to have a panic attack or feel down as everyone in my life know what is happening ,people who have diabetes or heart problems are not ashamed of it,so why should we be ashamed it is just another illness,see your gp urgently and get referred to therapy groups ,you will meet a lot of good people and will understand you are not alone.it will get better trust me ,asking for help is not a weakness but strenth,so take care and good luck.'

# %%
df20[['body', 'tags']][1:2]
# Out:
#                                                 body  \
# 1  Thanks for that. I could relate to the depress...
#
#                                         tags
# 1  depressionanxietyself esteem & confidence

# %%
hey = 'losses'
'losse' in hey
# Out:
# True

# %%
df20['body']
# Out:
# 0     David Carbonell, a psychologist who does a lot...
# 1     Thanks for that. I could relate to the depress...
# 2     ok, I read the article... it's very interestin...
# 3     Thanks for sharing the article, for me i got a...
# 4     Hi I've just read the article and now I am mor...
# 5     Anxiety and Depression usually go hand in hand...
# 6     \n\nqualityfactor said:\n\n\n\n\t\t\tAnxiety a...
# 7     I would agree with that.On an occasion before ...
# 8     As a young man I would say I had extreme anxie...
# 9                           Very interesting thank you.
# 10    hi i suffered from depression for best part of...
# 11    I have been told I have depression (though I d...
# 12    i been treated for depression off and on for o...
# 13    mischief.I read the webpage and found that I c...
# 14    I don't knowingly get anxious but my body does...
# 15    \n\nMischief said:\n\n\n\nAnxiety and Depressi...
# 16    I have both Anxiety & Depression along with Bo...
# 17    Joanna,first thing towards getting better is t...
# 18    Life gives you lemons you now have lemons\n\nL...
# 19    \n\nMarchhare said:\n\n\n\n\t\t\tI don't knowi...
# Name: body, dtype: object
